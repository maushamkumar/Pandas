# %% [markdown]
# <a href="https://colab.research.google.com/github/maushamkumar/Pandas/blob/main/string_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# What are vectorised operations?
a = np.array([1, 2, 3, 4])
a * 3   # This is also a vectorised operation
# Out:
# array([ 3,  6,  9, 12])

# %%
# problem in vectorized operations in vanilla python
s = ['cat', 'mat', None, 'rat']
[i.startswith('c') for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-562fca5e1f83> in <cell line: 3>()
#       1 # problem in vectorized operations in vanilla python
#       2 s = ['cat', 'mat', None, 'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# <ipython-input-4-562fca5e1f83> in <listcomp>(.0)
#       1 # problem in vectorized operations in vanilla python
#       2 s = ['cat', 'mat', None, 'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
# How pandas solves this issue?
# str is string accessor
s = pd.Series(['cat', 'mat', None, 'rat'])
s.str.startswith('c')

# This is not only working on this data also it's fast and optimized
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df = pd.read_csv('/content/train.csv')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# Common Functions
# lower/upper/capitalize/title
# len
# strip

df['Name'].str.lower()
df['Name'].str.upper()
df['Name'].str.capitalize()
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# len ->
# Find that passenger whose name is bigger than every one of the other passengers
df['Name'].str.len()
df['Name'].str.len().max()
df['Name'][df['Name'].str.len() == 82][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a872f4cb6181> in <cell line: 5>()
#       3 df['Name'].str.len()
#       4 df['Name'].str.len().max()
# ----> 5 df['Name'][df['Name'].str.len() == 82][0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
# strip
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# split -> get
df['last_name'] = df['Name'].str.split(',').str.get(0)

# %%
df['Name'].str.split(',').str.get(1)
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(1).str.split(' ')
# This looks awkward because of space
# Out:
# 0                                  [, Mr., Owen, Harris]
# 1      [, Mrs., John, Bradley, (Florence, Briggs, Tha...
# 2                                       [, Miss., Laina]
# 3            [, Mrs., Jacques, Heath, (Lily, May, Peel)]
# 4                                [, Mr., William, Henry]
#                              ...
# 886                                     [, Rev., Juozas]
# 887                           [, Miss., Margaret, Edith]
# 888                [, Miss., Catherine, Helen, "Carrie"]
# 889                                [, Mr., Karl, Howell]
# 890                                     [, Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
# using this we have removed the space
df['Name'].str.split(',').str.get(1).str.strip()
# Out:
# 0                                 Mr. Owen Harris
# 1      Mrs. John Bradley (Florence Briggs Thayer)
# 2                                     Miss. Laina
# 3              Mrs. Jacques Heath (Lily May Peel)
# 4                               Mr. William Henry
#                           ...
# 886                                   Rev. Juozas
# 887                          Miss. Margaret Edith
# 888                Miss. Catherine Helen "Carrie"
# 889                               Mr. Karl Howell
# 890                                   Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(1).str.strip().str.split(" ", n=1) # n tell how many split you want.
# Out:
# 0                                 [Mr., Owen Harris]
# 1      [Mrs., John Bradley (Florence Briggs Thayer)]
# 2                                     [Miss., Laina]
# 3              [Mrs., Jacques Heath (Lily May Peel)]
# 4                               [Mr., William Henry]
#                            ...
# 886                                   [Rev., Juozas]
# 887                          [Miss., Margaret Edith]
# 888                [Miss., Catherine Helen "Carrie"]
# 889                               [Mr., Karl Howell]
# 890                                   [Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(1).str.strip().str.split(" ", n=1, expand=True) # This expand will convert into a dataframe
# Out:
#          0                                      1
# 0      Mr.                            Owen Harris
# 1     Mrs.  John Bradley (Florence Briggs Thayer)
# 2    Miss.                                  Laina
# 3     Mrs.          Jacques Heath (Lily May Peel)
# 4      Mr.                          William Henry
# ..     ...                                    ...
# 886   Rev.                                 Juozas
# 887  Miss.                         Margaret Edith
# 888  Miss.               Catherine Helen "Carrie"
# 889    Mr.                            Karl Howell
# 890    Mr.                                Patrick
#
# [891 rows x 2 columns]

# %%
df[['title', 'Name']] = df['Name'].str.split(',').str.get(1).str.strip().str.split(" ", n=1, expand=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                   Name  \
# 0            1         0       3                            Owen Harris
# 1            2         1       1  John Bradley (Florence Briggs Thayer)
# 2            3         1       3                                  Laina
# 3            4         1       1          Jacques Heath (Lily May Peel)
# 4            5         0       3                          William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    last_name  title
# 0     Braund    Mr.
# 1    Cumings   Mrs.
# 2  Heikkinen  Miss.
# 3   Futrelle   Mrs.
# 4      Allen    Mr.

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
# replace
df['title'].str.replace('Ms', 'Miss')
df['title'].str.replace('Mlle', 'Miss')
# Out:
# 0        Mr.
# 1       Mrs.
# 2      Miss.
# 3       Mrs.
# 4        Mr.
#        ...
# 886     Rev.
# 887    Miss.
# 888    Miss.
# 889      Mr.
# 890      Mr.
# Name: title, Length: 891, dtype: object

# %%
# filtering
# Find those passenger whose name start with a
# startswith/endswith
df[df['Name'].str.startswith('A')]
# isdigit/isalpha
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 13            14         0       3         Anders Johan    male  39.0      1
# 22            23         1       3         Anna "Annie"  female  15.0      0
# 35            36         0       1      Alexander Oskar    male  42.0      1
# 38            39         0       3        Augusta Maria  female  18.0      2
# 61            62         1       1               Amelie  female  38.0      0
# ..           ...       ...     ...                  ...     ...   ...    ...
# 842          843         1       1              Augusta  female  30.0      0
# 845          846         0       3              Anthony    male  42.0      0
# 866          867         1       2             Asuncion  female  27.0      1
# 875          876         1       3  Adele Kiamie "Jane"  female  15.0      0
# 876          877         0       3        Alfred Ossian    male  20.0      0
#
#      Parch         Ticket     Fare Cabin Embarked      last_name  title
# 13       5         347082  31.2750   NaN        S      Andersson    Mr.
# 22       0         330923   8.0292   NaN        Q        McGowan  Miss.
# 35       0         113789  52.0000   NaN        S      Holverson    Mr.
# 38       0         345764  18.0000   NaN        S  Vander Planke  Miss.
# 61       0         113572  80.0000   B28      NaN          Icard  Miss.
# ..     ...            ...      ...   ...      ...            ...    ...
# 842      0         113798  31.0000   NaN        C       Serepeca  Miss.
# 845      0      C.A. 5547   7.5500   NaN        S         Abbing    Mr.
# 866      0  SC/PARIS 2149  13.8583   NaN        C   Duran y More  Miss.
# 875      0           2667   7.2250   NaN        C          Najib  Miss.
# 876      0           7534   9.8458   NaN        S     Gustafsson    Mr.
#
# [95 rows x 14 columns]

# %%
# apllying regs
# contains
# search john -> both case
# find last names with start and end char vowel

# %%
df[df['Name'].str.contains('john', case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# 574          575         0       3
# 581          582         1       1
# 583          584         0       1
# 586          587         0       2
# 594          595         0       2
# 613          614         0       3
# 624          625         0       3
# 657          658         0       3
# 694          695         0       1
# 698          699         0       1
# 700          701         1       1
# 733          734         0       2
# 760          761         0       3
# 765          766         1       1
# 818          819         0       3
# 822          823         0       1
# 825          826         0       3
# 848          849         0       2
# 864          865         0       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1          John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 41   William John Robert (Dorothy Ann Wonnacott)  female  27.0      1      0
# 45                                  William John    male   NaN      0      0
# 98                       John T (Ada Julia Bone)  female  34.0      0      1
# 112                                   David John    male  22.0      0      0
# 117                          William John Robert    male  29.0      1      0
# 160                                John Hatfield    male  44.0      0      1
# 162                                  John Viktor    male  26.0      0      0
# 165                 Frank John William "Frankie"    male   9.0      0      2
# 168                                       John D    male   NaN      0      0
# 188                                         John    male  40.0      1      1
# 212                                   John Henry    male  22.0      0      0
# 226                                 William John    male  19.0      0      0
# 227                          John Hall ("Henry")    male  20.5      0      0
# 324                               George John Jr    male   NaN      8      2
# 328               Frank John (Emily Alice Brown)  female  31.0      1      1
# 401                                         John    male  26.0      0      0
# 418                                 William John    male  30.0      0      0
# 467                              John Montgomery    male  56.0      0      0
# 527                                         John    male   NaN      0      0
# 548                                   Frank John    male  33.0      1      1
# 549                               John Morgan Jr    male   8.0      1      1
# 550                              John Borland Jr    male  17.0      0      2
# 563                                         John    male   NaN      0      0
# 572                        John Irwin ("Irving")    male  36.0      0      0
# 574                           Alfred George John    male  16.0      0      0
# 581      John Borland (Marian Longstreth Morris)  female  39.0      1      1
# 583                                    John Hugo    male  36.0      0      0
# 586                                  John Denzil    male  47.0      0      0
# 594                                   John Henry    male  37.0      1      0
# 613                                         John    male   NaN      0      0
# 624                             David John "Dai"    male  21.0      0      0
# 657                             John (Catherine)  female  32.0      1      1
# 694                                         John    male  60.0      0      0
# 698                                 John Borland    male  49.0      1      1
# 700        John Jacob (Madeleine Talmadge Force)  female  18.0      1      0
# 733                                 William John    male  23.0      0      0
# 760                                         John    male   NaN      0      0
# 765                        John C (Anna Andrews)  female  51.0      1      0
# 818                       John Fredrik Alexander    male  43.0      0      0
# 822                                  John George    male  38.0      0      0
# 825                                         John    male   NaN      0      0
# 848                                         John    male  28.0      0      1
# 864                                 John William    male  24.0      0      0
#
#               Ticket      Fare    Cabin Embarked  last_name      title
# 1           PC 17599   71.2833      C85        C    Cumings       Mrs.
# 41             11668   21.0000      NaN        S     Turpin       Mrs.
# 45   S.C./A.4. 23567    8.0500      NaN        S     Rogers        Mr.
# 98            231919   23.0000      NaN        S     Doling       Mrs.
# 112           324669    8.0500      NaN        S     Barton        Mr.
# 117            11668   21.0000      NaN        S     Turpin        Mr.
# 160           371362   16.1000      NaN        S      Cribb        Mr.
# 162           347068    7.7750      NaN        S  Bengtsson        Mr.
# 165           363291   20.5250      NaN        S  Goldsmith    Master.
# 168         PC 17318   25.9250      NaN        S    Baumann        Mr.
# 188           364849   15.5000      NaN        Q     Bourke        Mr.
# 212        A/5 21174    7.2500      NaN        S     Perkin        Mr.
# 226        SW/PP 751   10.5000      NaN        S    Mellors        Mr.
# 227        A/5 21173    7.2500      NaN        S     Lovell        Mr.
# 324         CA. 2343   69.5500      NaN        S       Sage        Mr.
# 328           363291   20.5250      NaN        S  Goldsmith       Mrs.
# 401           341826    8.0500      NaN        S      Adams        Mr.
# 418            28228   13.0000      NaN        S   Matthews        Mr.
# 467           113792   26.5500      NaN        S      Smart        Mr.
# 527         PC 17483  221.7792      C95        S   Farthing        Mr.
# 548           363291   20.5250      NaN        S  Goldsmith        Mr.
# 549       C.A. 33112   36.7500      NaN        S     Davies    Master.
# 550            17421  110.8833      C70        C     Thayer        Mr.
# 563  SOTON/OQ 392082    8.0500      NaN        S    Simmons        Mr.
# 572         PC 17474   26.3875      E25        S      Flynn        Mr.
# 574       A/4. 20589    8.0500      NaN        S       Rush        Mr.
# 581            17421  110.8833      C68        C     Thayer       Mrs.
# 583            13049   40.1250      A10        C       Ross        Mr.
# 586           237565   15.0000      NaN        S     Jarvis        Mr.
# 594      SC/AH 29037   26.0000      NaN        S    Chapman        Mr.
# 613           370377    7.7500      NaN        Q     Horgan        Mr.
# 624            54636   16.1000      NaN        S      Bowen        Mr.
# 657           364849   15.5000      NaN        Q     Bourke       Mrs.
# 694           113800   26.5500      NaN        S       Weir       Col.
# 698            17421  110.8833      C68        C     Thayer        Mr.
# 700         PC 17757  227.5250  C62 C64        C      Astor       Mrs.
# 733            28425   13.0000      NaN        S   Berriman        Mr.
# 760           358585   14.5000      NaN        S   Garfirth        Mr.
# 765            13502   77.9583      D11        S   Hogeboom       Mrs.
# 818           C 7075    6.4500      NaN        S       Holm        Mr.
# 822            19972    0.0000      NaN        S   Reuchlin  Jonkheer.
# 825           368323    6.9500      NaN        Q      Flynn        Mr.
# 848           248727   33.0000      NaN        S     Harper       Rev.
# 864           233866   13.0000      NaN        S       Gill        Mr.

# %%
df[df['last_name'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 30            31         0       1                                  Manuel E
# 49            50         0       3                  Josef (Josefine Franchi)
# 207          208         1       3                             Nassef Cassem
# 210          211         0       3                                     Ahmed
# 353          354         0       3                                     Josef
# 493          494         0       1                                     Ramon
# 518          519         1       2  William A (Florence "Mary" Agnes Hughes)
# 784          785         0       3                                   William
# 840          841         0       3                             Ilmari Rudolf
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked  \
# 30     male  40.0      0      0            PC 17601  27.7208   NaN        C
# 49   female  18.0      1      0              349237  17.8000   NaN        S
# 207    male  26.0      0      0                2699  18.7875   NaN        C
# 210    male  24.0      0      0  SOTON/O.Q. 3101311   7.0500   NaN        S
# 353    male  25.0      1      0              349237  17.8000   NaN        S
# 493    male  71.0      0      0            PC 17609  49.5042   NaN        C
# 518  female  36.0      1      0              226875  26.0000   NaN        S
# 784    male  25.0      0      0  SOTON/O.Q. 3101312   7.0500   NaN        S
# 840    male  20.0      0      0    SOTON/O2 3101287   7.9250   NaN        S
#
#           last_name title
# 30        Uruchurtu  Don.
# 49   Arnold-Franchi  Mrs.
# 207        Albimona   Mr.
# 210             Ali   Mr.
# 353  Arnold-Franchi   Mr.
# 493    Artagaveytia   Mr.
# 518           Angle  Mrs.
# 784             Ali   Mr.
# 840        Alhomaki   Mr.

# %%
# slicing
df['Name'].str[:4]
# Out:
# 0      Owen
# 1      John
# 2      Lain
# 3      Jacq
# 4      Will
#        ...
# 886    Juoz
# 887    Marg
# 888    Cath
# 889    Karl
# 890    Patr
# Name: Name, Length: 891, dtype: object
