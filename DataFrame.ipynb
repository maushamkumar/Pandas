# %% [markdown]
# <a href="https://colab.research.google.com/github/maushamkumar/Pandas/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating DataFrame

# %%
# Using lists
student_data = [
    [100, 60, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2]

]

pd.DataFrame(student_data, columns = ['math_score', 'reading_score', 'writing_score'])
# Out:
#    math_score  reading_score  writing_score
# 0         100             60             10
# 1          90             70              7
# 2         120            100             14
# 3          80             50              2

# %%
# using dicts
student_data = {
    'math_score': [100, 90, 120, 80],
    'reading_score': [60, 70, 100, 50],
    'writing_score': [10, 7, 14, 2]
}

pd.DataFrame(student_data)
# Out:
#    math_score  reading_score  writing_score
# 0         100             60             10
# 1          90             70              7
# 2         120            100             14
# 3          80             50              2

# %%
# using read_csv
movies = pd.read_csv('/content/movies (2).csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')

# %% [markdown]
# # DataFrame Attributes and Methods

# %%
# shape => shape of the data frame (no of rows and column )
movies.shape
ipl.shape
# Out:
# (950, 20)

# %%
# dtype => what is type of your data
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index => index of your data
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# column => column of your data
movies.columns
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# values => values of your dataFrame
movies.values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tial => top and bottom 5 rows
movies.head()
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movies.tail()
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample => random samples from the dataset usually we use this data when we have bias
movies.sample()
ipl.sample()
# Out:
#          ID           City        Date Season MatchNumber           Team1  \
# 390  980985  Visakhapatnam  2016-05-13   2016          43  Mumbai Indians
#
#                Team2                                              Venue  \
# 390  Kings XI Punjab  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
#
#          TossWinner TossDecision SuperOver      WinningTeam    WonBy  Margin  \
# 390  Mumbai Indians          bat         N  Kings XI Punjab  Wickets     7.0
#
#     method Player_of_Match                                       Team1Players  \
# 390    NaN      MP Stoinis  ['RG Sharma', 'UBT Chand', 'AT Rayudu', 'N Ran...
#
#                                           Team2Players          Umpire1  \
# 390  ['M Vijay', 'HM Amla', 'WP Saha', 'GJ Maxwell'...  HDPK Dharmasena
#
#        Umpire2
# 390  CK Nandan

# %%
# info => to get the information about the dataset
movies.info()
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull => to check the null values
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
ipl.isnull(

).sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicate
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
# rename => to rename the column (If you want to permanently change then use inplace=True) )
movies.rename(columns={"title_x":"Movie Title","title_y":"Release Year"})
# Out:
#                                Movie Title     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # Math methods

# %%
# sum => This will add all the values in the column if you want to add all the rows you need to use sum(axis = 1)
movies['imdb_rating'].sum()
# Out:
# 9053.099999999999

# %%
movies['imdb_rating'].mean()
# Out:
# 5.557458563535911

# %%
movies['imdb_rating'].min()
# Out:
# 0.0

# %%
movies['imdb_rating'].max()
# Out:
# 9.4

# %%
movies['imdb_rating'].median()
# Out:
# 5.6

# %%
movies['imdb_rating'].var()
# Out:
# 2.45739673123651

# %% [markdown]
# # Selecting cols from a DataFrame

# %%
# single columns
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies['imdb_rating']
# Out:
# 0       8.4
# 1       4.1
# 2       6.1
# 3       6.0
# 4       7.3
#        ...
# 1624    4.9
# 1625    3.0
# 1626    6.1
# 1627    7.4
# 1628    9.0
# Name: imdb_rating, Length: 1629, dtype: float64

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# If you fetch a column then it is a series data type
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# How to fetch multiple column
# If you fetch multiple column then it is a DataFrame data type
# Order does matter while fetching multiple-column
movies[['title_x', 'runtime','imdb_rating']]
# Out:
#                                    title_x runtime  imdb_rating
# 0                 Uri: The Surgical Strike     138          8.4
# 1                            Battalion 609     131          4.1
# 2     The Accidental Prime Minister (film)     112          6.1
# 3                          Why Cheat India     121          6.0
# 4                          Evening Shadows     102          7.3
# ...                                    ...     ...          ...
# 1624                 Tera Mera Saath Rahen     148          4.9
# 1625                  Yeh Zindagi Ka Safar     146          3.0
# 1626                       Sabse Bada Sukh      \N          6.1
# 1627                                 Daaka     136          7.4
# 1628                              Humsafar      35          9.0
#
# [1629 rows x 3 columns]

# %%
ipl[['Team1', 'Team2', 'TossWinner', 'TossDecision', 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                       TossWinner TossDecision                  WinningTeam
# 0               Rajasthan Royals          bat               Gujarat Titans
# ...

# %% [markdown]
# # Selecting rows from a DataFrame
# * **iloc** - searches using index positions
# * **loc** - searches using index labels

# %%
# using dicts
student_data = {
    'name': ['Mausham', 'Rani', 'Gopal', 'Rishu'],
    'age': [25, 30, 28, 35],
    'math_score': [100, 90, 120, 80],
    'reading_score': [60, 70, 100, 50],
    'writing_score': [10, 7, 14, 2]
}

students = pd.DataFrame(student_data)
students.set_index('name', inplace=True) # Inplace is use for parament change

# %%
students
# Out:
#          age  math_score  reading_score  writing_score
# name
# Mausham   25         100             60             10
# Rani      30          90             70              7
# Gopal     28         120            100             14
# Rishu     35          80             50              2

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[5:16:2]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 7          Bombairiya  tt4971258
# 9    Thackeray (film)  tt7777196
# 11          Gully Boy  tt2395469
# 13      Total Dhamaal  tt7639372
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7          https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9    https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# ...

# %%
movies.iloc[5:16:5]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 10             Amavas  tt8396186
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link title_y original_title  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)    Soni           Soni
# 10             https://en.wikipedia.org/wiki/Amavas  Amavas         Amavas
# 15  https://en.wikipedia.org/wiki/Badla_(2019_film)   Badla          Badla
#
#     is_adult  year_of_release runtime               genres  imdb_rating  \
# 5          0             2018      97                Drama          7.2
# 10         0             2019     134      Horror|Thriller          2.8
# 15         0             2019     118  Crime|Drama|Mystery          7.9
#
# ...

# %%
# Fancy indexing
movies.iloc[[0, 4, 5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc => index label

# %%
students
# Out:
#          age  math_score  reading_score  writing_score
# name
# Mausham   25         100             60             10
# Rani      30          90             70              7
# Gopal     28         120            100             14
# Rishu     35          80             50              2

# %%
students.loc['Rani']
# Out:
# age              30
# math_score       90
# reading_score    70
# writing_score     7
# Name: Rani, dtype: int64

# %%
# Fancy loc
students.loc[['Rani', 'Gopal']]
# Out:
#        age  math_score  reading_score  writing_score
# name
# Rani    30          90             70              7
# Gopal   28         120            100             14

# %%
# slicing loc
students.loc['Mausham':'Rishu']
# Out:
#          age  math_score  reading_score  writing_score
# name
# Mausham   25         100             60             10
# Rani      30          90             70              7
# Gopal     28         120            100             14
# Rishu     35          80             50              2

# %%
students.loc['Mausham':'Rishu': 2]
# Out:
#          age  math_score  reading_score  writing_score
# name
# Mausham   25         100             60             10
# Gopal     28         120            100             14

# %%
students.iloc[0]
# Out:
# age               25
# math_score       100
# reading_score     60
# writing_score     10
# Name: Mausham, dtype: int64

# %%
# default => iloc custom data =< loc

# %% [markdown]
# # Selecting both rows and cols

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# I want to first three movie but we need only three column data
movies.iloc[:3, :3] # first 3 rows and first 3 columns
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[:2, 'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering a DataFrame

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# Find all the final winners
mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# In one line
ipl[ipl['MatchNumber'] == 'Final'][['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# How many super over-finishers have occurred
ipl['SuperOver'].unique()
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# How many matches has csk won in kolkata?
ipl['City'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Kochi', 'Nagpur', 'Johannesburg', 'Centurion',
#        'Durban', 'Bloemfontein', 'Port Elizabeth', 'Kimberley',
#        'East London', 'Cape Town'], dtype=object)

# %%
(ipl[ipl['City'] == 'Kolkata']).head(2)
# Out:
#         ID     City        Date Season  MatchNumber  \
# 2  1312198  Kolkata  2022-05-25   2022   Eliminator
# 3  1312197  Kolkata  2022-05-24   2022  Qualifier 1
#
#                          Team1                 Team2                  Venue  \
# 2  Royal Challengers Bangalore  Lucknow Super Giants  Eden Gardens, Kolkata
# 3             Rajasthan Royals        Gujarat Titans  Eden Gardens, Kolkata
#
#              TossWinner TossDecision SuperOver                  WinningTeam  \
# 2  Lucknow Super Giants        field         N  Royal Challengers Bangalore
# 3        Gujarat Titans        field         N               Gujarat Titans
#
#      WonBy  Margin method Player_of_Match  \
# 2     Runs    14.0    NaN      RM Patidar
# 3  Wickets     7.0    NaN       DA Miller
#
#                                         Team1Players  \
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
# ...

# %%
(ipl[ipl['WinningTeam'] == 'Chennai Super Kings']).head(2)
# Out:
#          ID         City        Date Season MatchNumber                Team1  \
# 19  1304101  Navi Mumbai  2022-05-08   2022          55  Chennai Super Kings
# 28  1304092         Pune  2022-05-01   2022          46  Chennai Super Kings
#
#                   Team2                                          Venue  \
# 19       Delhi Capitals             Dr DY Patil Sports Academy, Mumbai
# 28  Sunrisers Hyderabad  Maharashtra Cricket Association Stadium, Pune
#
#              TossWinner TossDecision SuperOver          WinningTeam WonBy  \
# 19       Delhi Capitals        field         N  Chennai Super Kings  Runs
# 28  Sunrisers Hyderabad        field         N  Chennai Super Kings  Runs
#
#     Margin method Player_of_Match  \
# 19    91.0    NaN       DP Conway
# 28    13.0    NaN      RD Gaikwad
#
#                                          Team1Players  \
# 19  ['RD Gaikwad', 'DP Conway', 'S Dube', 'AT Rayu...
# 28  ['RD Gaikwad', 'DP Conway', 'MS Dhoni', 'RA Ja...
#
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# How many matches played Mumbai Indians at Mumbai
ipl[ipl['City'] == 'Mumbai'].shape[0]
# Out:
# 159

# %%
# How many matches mumbai won at home
ipl[(ipl['City'] == 'Mumbai') & (ipl['WinningTeam'] == 'Mumbai Indians')].shape[0]
# Out:
# 56

# %%
# Who has won maximum matches at Mumbai except Mumbai Indians

ipl[ipl['City'] == 'Mumbai']['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 56
# Chennai Super Kings            16
# Rajasthan Royals               16
# Royal Challengers Bangalore    12
# Sunrisers Hyderabad             8
# Delhi Capitals                  8
# Lucknow Super Giants            6
# Punjab Kings                    6
# Kolkata Knight Riders           6
# Gujarat Titans                  6
# Kings XI Punjab                 5
# Delhi Daredevils                3
# Pune Warriors                   3
# Deccan Chargers                 3
# Rising Pune Supergiant          2
# Gujarat Lions                   1
# Rising Pune Supergiants         1
# Kochi Tuskers Kerala            1
# Name: count, dtype: int64

# %%
# Let's find out how many matches CSK won at home pitch
ipl[ipl['City'] == 'Chennai']['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Chennai Super Kings            40
# Mumbai Indians                  7
# Royal Challengers Bangalore     5
# Kolkata Knight Riders           3
# Delhi Capitals                  2
# Kings XI Punjab                 2
# Delhi Daredevils                2
# Deccan Chargers                 2
# Punjab Kings                    1
# Sunrisers Hyderabad             1
# Pune Warriors                   1
# Rajasthan Royals                1
# Name: count, dtype: int64

# %%
ipl[ipl['City'] == 'Chennai'].shape[0]
# Out:
# 67

# %%
# How many CSK and MI win if they play against each other
ipl[(ipl['Team1'] == 'Chennai Super Kings') & (ipl['Team2'] == 'Mumbai Indians')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians         12
# Chennai Super Kings     9
# Name: count, dtype: int64

# %%
# How many CSK and MI win if they play against each other
ipl[(ipl['Team1'] == 'Mumbai Indians') & (ipl['Team2'] == 'Chennai Super Kings')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians         8
# Chennai Super Kings    5
# Name: count, dtype: int64

# %%
# How many CSK and RCB win if they play against each other
ipl[(ipl['Team1'] == 'Chennai Super Kings') & (ipl['Team2'] == 'Royal Challengers Bangalore')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Chennai Super Kings            9
# Royal Challengers Bangalore    2
# Name: count, dtype: int64

# %%
ipl[(ipl['Team1'] == 'Royal Challengers Bangalore') & (ipl['Team2'] == 'Chennai Super Kings')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Chennai Super Kings            10
# Royal Challengers Bangalore     8
# Name: count, dtype: int64

# %%
# How many CSK and RCB win if they play against each other
ipl[(ipl['Team1'] == 'Royal Challengers Bangalore') & (ipl['Team2'] == 'Mumbai Indians')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 11
# Royal Challengers Bangalore     7
# Name: count, dtype: int64

# %%
ipl[(ipl['Team1'] == 'Mumbai Indians') & (ipl['Team2'] == 'Royal Challengers Bangalore')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Royal Challengers Bangalore    6
# Mumbai Indians                 6
# Name: count, dtype: int64

# %%
ipl[(ipl['City'] == 'Bengaluru') | (ipl['City'] == 'Bangalore')].shape[0]
# Out:
# 80

# %%
ipl[(ipl['City'] == 'Bengaluru') | (ipl['City'] == 'Bangalore')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Royal Challengers Bangalore    37
# Mumbai Indians                  9
# Kolkata Knight Riders           8
# Chennai Super Kings             5
# Kings XI Punjab                 5
# Rajasthan Royals                4
# Delhi Daredevils                3
# Sunrisers Hyderabad             2
# Delhi Capitals                  1
# Gujarat Lions                   1
# Rising Pune Supergiant          1
# Deccan Chargers                 1
# Name: count, dtype: int64

# %%
ipl[((ipl['City'] == 'Bengaluru') | (ipl['City'] == 'Bangalore')) & (ipl['Team2'] == 'Mumbai Indians')]['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 7
# Royal Challengers Bangalore    2
# Chennai Super Kings            1
# Name: count, dtype: int64

# %%
# toss winner is match winner in percentage
# Who won the toss and how many matches has he won the match
ipl.head(

)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0]) * 100
# Out:
# 51.473684210526315

# %%
# toss winner is match winner in percentage let's find out for particular year
(ipl[(ipl['TossWinner'] == ipl['WinningTeam']) & (ipl['Season'] == '2020')] / ipl[(ipl['Season'] == '2020')].shape[0]) * 100
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
ipl[ipl['Season'] == '2022'].shape[0]
# Out:
# 74

# %%
ipl[(ipl['TossWinner'] == ipl['WinningTeam']) & (ipl['Season'] == '2020')]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-165-91641111512a> in <cell line: 11>()
#       9
#      10 # Calculate the percentage
# ---> 11 percentage = (toss_winner_is_match_winner / total_matches_2020) * 100
#      12
#      13 print(f"Toss winner is match winner in 2020: {percentage:.2f}%")
#
# ZeroDivisionError: division by zero
